# %% [markdown]
# ![welcome.png](attachment:ddaf6160-86e5-4915-8e18-56a2cd6b2ad0.png)

# %% [markdown]
# # Welcome the evening course on machine learning for geosciences!
# Part of the CoCreate project.
