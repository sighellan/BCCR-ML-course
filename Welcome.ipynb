# %% [markdown]
# <img src="extras/banner.png" alt="BCCR course banner" style="width: 100%; max-width: 1600px; height: auto; display: block; margin: 0;" />

# %% [markdown]
# # Welcome the the BCCR Training Programme in Machine Learning for Geosciences - 2026
# Funded by the Bjerknes Centre for Climate Research
#
# ## Beginners' course
# ### Jupyterlab links
# #### $\quad\rightarrow$ Module 1: Introduction to Machine Learning
#
# |  | Exercise notebook | Solution notebook |
# | --- | --- | --- |
# | D1-01 Linear Regression Example | [Link to exercise](lecture_exercises/exercises/D1-01_linear-regression-example.ipynb) | [Link to solution](lecture_exercises/solutions/D1-01_linear-regression-example.ipynb) |
# | D1-02 Linear Regression | [Link to exercise](lecture_exercises/exercises/D1-02_linear-regression.ipynb) | [Link to solution](lecture_exercises/solutions/D1-02_linear-regression.ipynb) |
# | D1-03 Logistic Regression | [Link to exercise](lecture_exercises/exercises/D1-03_logistic-regression.ipynb) | [Link to solution](lecture_exercises/solutions/D1-03_logistic-regression.ipynb) |
# | D1-04 Decision Tree | [Link to exercise](lecture_exercises/exercises/D1-04_decision-tree.ipynb) | [Link to solution](lecture_exercises/solutions/D1-04_decision-tree.ipynb) |
# | D1-05 KMeans | [Link to exercise](lecture_exercises/exercises/D1-05_kmeans.ipynb) | [Link to solution](lecture_exercises/solutions/D1-05_kmeans.ipynb) |
#
# #### $\quad\rightarrow$ Module 2: Introduction to Deep Learning and Neural Networks
# |  | Exercise notebook | Solution notebook |
# | --- | --- | --- |
# | D2-01 Data Preprocessing| [Link to exercise](lecture_exercises/exercises/D2-01_data-preprocessing.ipynb) | [Link to solutions](lecture_exercises/solutions/D2-01_data-preprocessing.ipynb) |
# | D2-02 Neural Network| [Link to exercise](lecture_exercises/exercises/D2-02-NN/D2-02_neural-network-example.ipynb) | [Link to solutions](lecture_exercises/solutions/D2-02-NN/D2-02_neural-network-example.ipynb) |
#
# ### Google collab links
# #### $\quad\rightarrow$ Module 1: Introduction to Machine Learning
# |  | Exercise notebook | Solution notebook |
# | --- | --- | --- |
# | D1-01 Linear Regression Example | [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D1-01_linear-regression-example.ipynb) | [Link to solution](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D1-01_linear-regression-example.ipynb) |
# | D1-02 Linear Regression | [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D1-02_linear-regression.ipynb) | [Link to solution](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D1-02_linear-regression.ipynb) |
# | D1-03 Logistic Regression | [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D1-03_logistic-regression.ipynb) | [Link to solution](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D1-03_logistic-regression.ipynb) |
# | D1-04 Decision Tree | [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D1-04_decision-tree.ipynb) | [Link to solution](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D1-04_decision-tree.ipynb) |
# | D1-05 KMeans | [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D1-05_kmeans.ipynb) | [Link to solution](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D1-05_kmeans.ipynb) |
#
# #### $\quad\rightarrow$ Module 2: Introduction to Deep Learning and Neural Networks
# |  | Exercise notebook | Solution notebook |
# | --- | --- | --- |
# | D2-01 Data Preprocessing| [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D2-01_data-preprocessing.ipynb) | [Link to solutions](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D2-01_data-preprocessing.ipynb) |
# | D2-02 Neural Network| [Link to exercise](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/exercises/D2-02-NN/D2-02_neural-network-example.ipynb) | [Link to solutions](https://colab.research.google.com/github/rguilcas/BCCR-ML-course/blob/collab/lecture_exercises/solutions/D2-02-NN/D2-02_neural-network-example.ipynb) |
#
#
#
#
#
# ### $\quad\rightarrow$ Module 3+4: Group Projects
# | Energy Consumption Prediction |  River Streamflow Prediction |  Weather Images Classification |
# | --- |--- |--- |
# |[Link to notebook](projects/EnergyConsumptionPrediction/project_notebook.ipynb)|[Link to notebook](projects/RiverStreamflowPrediction/project_notebook.ipynb)|[Link to noteobok](projects/WeatherImagesClassification/start_here.ipynb)|
