# %%
# Unzip data
# !tar -xvf data/dataset.tar.gz

# %%
# Optionally, you can also preprocess the data.
# This generates some files that allocate data to train, val and test.
# However, these have already been generated for you so there is no need
# to run the script unless you've changed the preprocessing.
# !python src/preprocess_data.py
